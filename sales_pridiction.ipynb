# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Advertising.csv')

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.head(9)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data.values
# Out:
# array([[  1. , 230.1,  37.8,  69.2,  22.1],
#        [  2. ,  44.5,  39.3,  45.1,  10.4],
#        [  3. ,  17.2,  45.9,  69.3,   9.3],
#        [  4. , 151.5,  41.3,  58.5,  18.5],
#        [  5. , 180.8,  10.8,  58.4,  12.9],
#        [  6. ,   8.7,  48.9,  75. ,   7.2],
#        [  7. ,  57.5,  32.8,  23.5,  11.8],
#        [  8. , 120.2,  19.6,  11.6,  13.2],
#        [  9. ,   8.6,   2.1,   1. ,   4.8],
#        [ 10. , 199.8,   2.6,  21.2,  10.6],
#        [ 11. ,  66.1,   5.8,  24.2,   8.6],
#        [ 12. , 214.7,  24. ,   4. ,  17.4],
#        [ 13. ,  23.8,  35.1,  65.9,   9.2],
#        [ 14. ,  97.5,   7.6,   7.2,   9.7],
#        [ 15. , 204.1,  32.9,  46. ,  19. ],
#        [ 16. , 195.4,  47.7,  52.9,  22.4],
#        [ 17. ,  67.8,  36.6, 114. ,  12.5],
#        [ 18. , 281.4,  39.6,  55.8,  24.4],
#        [ 19. ,  69.2,  20.5,  18.3,  11.3],
#        [ 20. , 147.3,  23.9,  19.1,  14.6],
#        [ 21. , 218.4,  27.7,  53.4,  18. ],
# ...

# %%
print(data.isnull().sum())
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
data .describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# Check column names
print(data.columns)

# Use the correct column name for 'sales'
data['Sales'] = label_encoder.fit_transform(data['Sales'])  # Ensure you replace 'Sales' with the correct name
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')
# C:\Users\Shubhi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Shubhi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation matrix to check relationships between variables
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# Scatter plot for 'Advertising_Spend' vs 'Sales'
plt.figure(figsize=(8,6))
sns.scatterplot(x=data['Advertising_Spend'], y=data['Sales'])
plt.title('Advertising Spend vs Sales')
plt.show()

# Scatter plot for 'Platform' vs 'Sales' (if it's numerical or ordinal)
plt.figure(figsize=(8,6))
sns.boxplot(x=data['Platform'], y=data['Sales'])
plt.title('Platform vs Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Advertising_Spend'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 12
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data for Actual Sales and Predicted Sales
np.random.seed(42)  # Set seed for reproducibility
n_samples = 50  # Number of data points
actual_sales = np.random.randint(100, 500, size=n_samples)  # Random actual sales
predicted_sales = actual_sales + np.random.randint(-50, 50, size=n_samples)  # Predicted with some noise

# Create the plot
plt.figure(figsize=(10,6))
plt.plot(actual_sales, label='Actual Sales', color='blue', linestyle='-')
plt.plot(predicted_sales, label='Predicted Sales', color='orange', linestyle='--')
plt.xlabel("Sample Index")
plt.ylabel("Sales")
plt.title("Actual vs Predicted Sales")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate performance metrics
mse = mean_squared_error(actual_sales, predicted_sales)
mae = mean_absolute_error(actual_sales, predicted_sales)
r2 = r2_score(actual_sales, predicted_sales)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 929.44
# Mean Absolute Error: 26.2
# R-squared: 0.920206635829899

# %%
# Calculate residuals
residuals = actual_sales - predicted_sales

# Plot residuals
plt.figure(figsize=(8,6))
plt.hist(residuals, bins=20, edgecolor='k', alpha=0.7)
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()
